# %%
#
name = "Ravi"
age =  20
# my name and i am a 20 years old
marks =[85,70,74,89,90]
print(" My name " ,name , " and i am a " , str(age) , " years old ")
# Out:
#  My name  Ravi  and i am a  20  years old

# %%
## output formatting
# 1. odd style formatting(using comma)
name = "Ravi"
age =  20
# my name and i am a 20 years old
marks =[85,70,74,89,90]
print("My name" ,name , "and i am a" , str(age) , "years old")
# Out:
# My name Ravi and i am a 20 years old

# %%
# 1.access specifiers
#integer - %d
#float -%f
#string -%s
name = "Ravi"
age =  20
# my name and i am a 20 years old
marks =[85,70,74,89,90]
print("My name %s and i am a %d years old"%(name, age))
# Out:
# My name Ravi and i am a 20 years old

# %%
#output formatting
#3. Dot format
name = "Ravi"
age =  20
marks =[85,70,74,89,90]
# my name and i am a 20 years old
print("My name {} and i am a {} years old".format(name, age))
print("My name {} and i am a {} years old".format(age, name))
# Out:
# My name Ravi and i am a 20 years old
# My name 20 and i am a Ravi years old

# %%
#4. f- format
name = "Ravi"
age =  20
marks =[85,70,74,89,90]
# my name and i am a 20 years old
percentage = 98.2568
print(f"My name {name}, and i an a {age} years old and my percentage is {percentage}")
print(f"My name {name}, and i an a {age} years old and my percentage is {percentage:.2f}")
# Out:
# My name Ravi, and i an a 20 years old and my percentage is 98.2568
# My name Ravi, and i an a 20 years old and my percentage is 98.26

# %%
# num = int(input())  # skip input while testing
num  # test with 
if num >= 0:
    print(f'{num} is +ve')
if num <=0:
    print(f'{num} is -ve')
else:
    print("zero")
# Out:
# 15 is +ve
# zero

# %%
print("Hello")
# Out:
# Hello

# %%
#
#num = int(input())
if num % 3 == 0 and num % 5 == 0:
    print(f"{num} divisible with both 3 and 5")
else:
    print(f"{num} not divisible with both 3 and 5")
# Out:
# 10 not divisible with both 3 and 5

# %%
name = input("Enter your name: ")
print(name)

# %%
num = 15  # skip input while testing
if num % 3 == 0 and num % 5 == 0:
    print(f"{num} divisible with both 3 and 5")
else:
    print(f"{num} not divisible by both 3 and 5")
# Out:
# 15 divisible with both 3 and 5

# %%
#num = int(input())
val = num**0.5
print(val)
if val == int(val):
    print(f"{num} is perfect square")
else:
    print(f"{num} is not perfect square")
# Out:
# 3.872983346207417
# 15 is not perfect square

# %%
num = 15  # skip input while testing
if num *3 == 0 and num *5 == 0:
    print(f"{num} multiple with both 3 and 5")
else:
    print(f"{num} not multiple by both 3 and 5")
# Out:
# 15 not multiple by both 3 and 5

# %%
num = int(input()) # skip input while tesitng
if num % 2 == 0:
    print(f"{num} is even")
if num % 2 == 1:
    print(f"{num} is odd")
# Out:
#  4
# 4 is even

# %%
num = int(input())   
if num % 3 == 0:
    print("Fizz")
elif num % 5 == 0:
    print("Buzz")
elif num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
else:
    print("num")
# Out:
#  4
# num

# %%
num = int(input()) # skip input while tesitng
if num > 0:
    print("+ve")
if num < 0:
    print("-ve")
else:
    print("zero")
# Out:
#  4
# +ve
# zero

# %%
num = int(input())
if num >=0 and num % 2 ==0:
    print(f'even {num} is even number')
elif num >=0:
    print(f'{num} is odd number')
elif num < 0:
    print(f'{num} is negative number')
else:
    print("zero")
# Out:
#  5
# 5 is odd number

# %%
num = int(input())
if num > 0 and num % 2==0:
    print(f"{num} is +ve even")
elif num < 0 and num % 2 ==0:
    print(f"{num} is -ve even")
else:
    print("zero")
# Out:
#  4
# 4 is +ve even

# %%
# find the smallest number among the three numbers
a = int(input())
b = int(input())
c = int(input())

if a <= b and a <= c:
    print("smallest number is a")
elif b <= a and b <= c:
    print("smallest number is b")
elif c <= b and c <= a:
    print("smallest number is c")
else:
    print("among the smallest number")
# Out:
#  90
#  10
#  30
# smallest number is b

# %%
num = int(input())
if num >0:
    if num % 2 ==0:
        print(f"{num} is +ve even")
    else:
        print(f"{num} is -ve even")
else:
    if num % 2 ==0:
        print(f"{num} is -ve even")
    else:
        print(f"{num} is -ve odd")
# Out:
#  -100
# -100 is -ve even

# %%
n1, n2, n3 = map(int,input().split())
if n1 % 2:
    print(f"{n1} is odd")
else:
    print(f"{n1} is even")
if n2 % 2:
    print(f"{n2} is odd")
else:
    print(f"{n2} is even")
if n3 % 2:
    print(f"{n3} is odd")
else:
    print(f"{n3} is even")
# Out:
#  11
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 n1, n2, n3 = map(int,input().split())
#       2 if n1 % 2:
#       3     print(f"{n1} is odd")
#       4 else:
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
if 1:
    print(0)
else:
    print(1)
# Out:
# 0
