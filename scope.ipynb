# %%
#sum = "heelo"
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
# local scope variable with in the scope,we can"t access in global scope
# we can access the local scope  variable with in the scope,we can"t access in global scope
def fun(x):
    x = x+1 # x is local scope
    return x
a = 10
res = fun(a)
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       4     x = x+1 # x is local scope
#       5     return x
#       6 a = 10
#       7 res = fun(a)
# ----> 8 print(x)
#
# NameError: name 'x' is not defined

# %%
# enclosing scope
def outer(x):
    y = 10# enclose scope
    def inner():
        a = 10# local scope
        z = y + a
        print(f"this is local scope:{z}")
    inner()
    y = y + x
    print(f"this is enclosing scope:{y}")
n = 5
outer(n)
# Out:
# this is local scope:20
# this is enclosing scope:15

# %%
# enclosing scope
def outer(x):
    x = 20# enclose scope
    def inner():
        x = 30# local scope
        z = x + x
        print(f"this is local scope:{z}")
    inner()
    y = x + x
    print(f"this is enclosing scope:{y}")
n = 5
outer(n)
# Out:
# this is local scope:60
# this is enclosing scope:40

# %%
# enclosing scope
def outer(x):
    x = 20# enclose scope
    def inner():
        #x = 30# local scope
        z = x + x
        print(f"this is local scope:{z}")
    inner()
    y = x + x
    print(f"this is enclosing scope:{y}")
n = 5
outer(n)
# Out:
# this is local scope:40
# this is enclosing scope:40

# %%
# global scope
x = 10
def outer():
    y = 20
    def inner():
        z = 20
        res = z + y + x
        print(f"this is local scope:{res}")
    res = y + x
    inner()
    print(f"this is enclosing scope:{res}")
outer()
# Out:
# this is local scope:50
# this is enclosing scope:30

# %%
# global scope
x = 10# global scope
def outer():
    y = 20# enclosing scope
    def inner():
        z = 20# local scope
        res = z + y + x
        print(f"this is local scope:{res}")
    y = y + x
    inner()
    print(f"this is enclosing scope:{y}")
outer()
# Out:
# this is local scope:60
# this is enclosing scope:30

# %%
# global scope
x = 10# global scope
def outer():
    #x = 20
    x = x+1
    print("this is local scope val:",x)
outer()
print("this is enclosing scope val:", x)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[23], line 7
#       3 def outer():
#       4     #x = 20
#       5     x = x+1
#       6     print("this is local scope val:",x)
# ----> 7 outer()
#       8 print("this is enclosing scope val:", x)
#
# Cell In[23], line 5, in outer()
#       3 def outer():
#       4     #x = 20
# ----> 5     x = x+1
#       6     print("this is local scope val:",x)
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
# update the global scope variable inside the local scope by using 'global' keyword
x = 10# global scope
def outer():
    global x
    x = x+1
    print("this is local scope val:",x)
outer()
print("this is enclosing scope val:", x)
# Out:
# this is local scope val: 11
# this is enclosing scope val: 11

# %%
x = 10# global scope
def outer():
    global x
    x = x+1
    print("this is enclosing scope val:",x)
outer()
print("this is local scope val:", x)
# Out:
# this is enclosing scope val: 11
# this is local scope val: 11

# %%
# trying to update enclosing scope variable in local scope
x = 10# global scope
def outer():
    y = 20# enclosing scope
    def inner():
        z = 20# local scope
        y =  y + 1
        print(f"this is local scope:{y}")
    #y = y + x
    inner()
    print(f"this is enclosing scope:{y}")
outer()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[30], line 12
#       8         print(f"this is local scope:{y}")
#       9     #y = y + x
#      10     inner()
#      11     print(f"this is enclosing scope:{y}")
# ---> 12 outer()
#
# Cell In[30], line 10, in outer()
#       6         z = 20# local scope
#       7         y =  y + 1
#       8         print(f"this is local scope:{y}")
#       9     #y = y + x
# ---> 10     inner()
#      11     print(f"this is enclosing scope:{y}")
#
# Cell In[30], line 7, in outer.<locals>.inner()
#       5     def inner():
#       6         z = 20# local scope
# ----> 7         y =  y + 1
#       8         print(f"this is local scope:{y}")
#
# UnboundLocalError: cannot access local variable 'y' where it is not associated with a value

# %%
# trying to update enclosing scope variable in local scope
x = 10# global scope
def outer():
    y = 20# enclosing scope
    def inner():
        nonlocal y
        z = 30# local scope
        y = y + 1
        print(f"this is local scope:{y}")
    y = y + x
    inner()
    y = y + x
    print(f"this is enclosing scope:{y}")
outer()
# Out:
# this is local scope:31
# this is enclosing scope:41

# %%
x = 20
def fun():
    x =30
