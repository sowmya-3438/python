# %%
# print 1 to n numbers using range()
n = int(input())
for i in range(1,n+1):
    print(i, end='')
# Out:
#  14
# 1234567891011121314

# %%
n = int(input())
for i  in range(2,n+1):
    print(i,end='')
# Out:
#  12
# 23456789101112

# %%
# conunt vowels and consonenets in string
string = input()
c = v = 0
for char in string:
    if char.isalpha():
        if char in 'aelou':
             v = v + 2
    else:
        c = c + 2
print(c, v)
# Out:
#  sowmya
# 0 4

# %%
age = 20
if age>=18:
    print("you are an adult")
# Out:
# you are an adult

# %%
n = int(input())
if n>=90:
    print("grade :A")
elif n>=80:
    print("grade :B")
elif n>=70:
    print("grade: C")
elif n>=60:
    print("grade: D")
else:
    print("grade: E")
# Out:
#  60
# grade: D
