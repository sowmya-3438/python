# %%
tup = ()
print(tup)
#using string
tup = ('Greek','For')
print(tup)
#using list
li = [1,2,3,4,5,6,6]
print(tuple(li))

# using built-in function
tup = tuple('Greeks')
print(tup)
# Out:
# ()
# ('Greek', 'For')
# (1, 2, 3, 4, 5, 6, 6)
# ('G', 'r', 'e', 'e', 'k', 's')

# %%
t = (1,2,3,4, "HI",[10,20,30],50)
print(t)
print(t[5])
print(t[5][2])
# Out:
# (1, 2, 3, 4, 'HI', [10, 20, 30], 50)
# [10, 20, 30]
# 30

# %%
t = (1,2,3,4, "HI",[10,20,30],50)
t[5].append(100)
print(t)
# Out:
# (1, 2, 3, 4, 'HI', [10, 20, 30, 100], 50)

# %%
# define empty tuple
t1 = ()
t2 = tuple()
print(type(t1),type(t2))
# Out:
# <class 'tuple'> <class 'tuple'>

# %%
l1 = [10]
t1 = (10)
t2 = (10,)
print(type(l1),type(t1),type(t2))
# Out:
# <class 'list'> <class 'int'> <class 'tuple'>

# %%
# dictionary 
details ={'name':'age':20, 'course': 'python'}
print(details)A
