# %% [markdown]
# Types of inheritance

# %%
# 1.single inheritance
#with implementation in child classdon't have constructor,In this case parent class constructor behave like child class constructor
#when child 
class person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def details(self):
        return f"MY name is {self.name} and i am a {self.age} years old"
#child class
class Student(person):
    pass
s = Student("sowmya", 20)
print(s.name)
print(s.details())
# Out:
# sowmya
# MY name is sowmya and i am a 20 years old

# %%
class person:
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
    def details(self):
        return f"MY name is {self.name} and i am a {self.age} years old"
#child class
class Student(person):
    def __init__(self, stdid, name, age):
        self.stdid= stdid
        self.name = name
        self.age = age
    
s = Student(101,"sowmya", 20)
print(s.name)
print(s.details())
# Out:
# sowmya
# MY name is sowmya and i am a 20 years old

# %%
class person:
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
    def details(self):
        return f"MY name is {self.name} and i am a {self.age} years old"
#child class
class Student(person):
    def __init__(self, stdid, name, age):
        self.stdid= stdid
        self.name = name
        self.age = age
p = person("lakshmi",21,"female")    
s = Student(101,"sowmya", 20)
print(s.name)
print(p.details())
s.gender = "female"
print(s.details())
# Out:
# sowmya
# MY name is lakshmi and i am a 21 years old
# MY name is sowmya and i am a 20 years old

# %%
#Inherete the parent class constructor in child child class by using super()
#super():This function is user to get the parent class
#parent class
class person:
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
    def details(self):
        return f"MY name is {self.name} and i am a {self.age} years old"
#child class
class Student(person):
    def __init__(self, stdid, name, age, gender):
        self.stdid= stdid
        super().__init__(name,age, gender)
    def percentage(self, marks:list):
        return sum(marks)/len(marks)
 
s = Student(101,"sowmya", 20,"female")
print(s.name)
print(p.details())
print(s.percentage([90,90,80]))
# Out:
# sowmya
# MY name is lakshmi and i am a 21 years old
# 86.66666666666667

# %%
employee
    company - cls attribute
    id, name, salary
teamlead
    id, name, salary, project
manager
    id, name, salary, project, no_projects

# %%
class Employee:
    company = "XYZ"  # Class Attribute

    def __init__(self, id, name, salary):
        self.id = id
        self.name = name
        self.salary = salary
    def calculate_salary(self, bonus=0):
         return self.salary+bonus
    
class TeamLead(Employee):
    def __init__(self, emp_id, name, salary, project_name):
        super().__init__(id, name, salary)
        self.project_name = project_name
    def project_status(self, status):
          return f"{self.project_name} project status: {status}% completed"
        
class Manager(TeamLead):
    def __init__(self, id, name, salary, project_name, no_projects):
        super().__init__(id, name, salary,project_name)
        self.no_projects = no_projects
 
e = Employee(101,"sowmya",35000)  
t = TeamLead(102,"lakshmi",45000,"Practice tracking project")
m = Manager(103,"sowmyalakshmi",55000,"Exam portal project", 5)
print(e.name, t.name, m.name)
print(e.calculate_salary())
print(t.calculate_salary(5000))
print(t.project_status(90))
print(m.calculate_salary(10000))
print(m.project_status(80))
# Out:
# sowmya lakshmi sowmyalakshmi
# 35000
# 50000
# Practice tracking project project status: 90% completed
# 65000
# Exam portal project project status: 80% completed

# %%
class Employee:
    company = "XYZ"  # Class Attribute

    def __init__(self, id, name, salary):
        self.id = id
        self.name = name
        self.salary = salary
    def calculate_salary(self, bonus=0):
         return self.salary+bonus
    
class TeamLead(Employee):
    def __init__(self, emp_id, name, salary, project_name):
        super().__init__(id, name, salary)
        self.project_name = project_name
    def project_status(self, status):
          return f"{self.project_name} project status: {status}% completed"
        
class Manager(TeamLead):
    def __init__(self, id, name, salary, project_name, no_projects):
        super().__init__(id, name, salary,project_name)
        self.no_projects = no_projects
 
e = Employee(101,"sowmya",35000)  
t = TeamLead(102,"lakshmi",45000,"Practice tracking project")
m = Manager(103,"sowmyalakshmi",55000,"Exam portal project", 5)
print(e.name, t.name, m.name)
print(e.calculate_salary())
print(t.calculate_salary(5000))
print(t.project_status(90))
print(m.calculate_salary(10000))
print(m.project_status(80))
# Out:
# sowmya lakshmi sowmyalakshmi
# 35000
# 50000
# Practice tracking project project status: 90% completed
# 65000
# Exam portal project project status: 80% completed

# %%
class Employee:
    company = "XYZ"  # Class Attribute

    def __init__(self, id, name, salary):
        self.id = id
        self.name = name
        self.salary = salary
    def calculate_salary(self, bonus=0):
         return self.salary+bonus
    
class TeamLead(Employee):
    def __init__(self, emp_id, name, salary, project_name):
        super().__init__(id, name, salary)
        self.project_name = project_name
    def project_status(self, status):
          return f"{self.project_name} project status: {status}% completed"
        
class Manager(TeamLead):
    def __init__(self, id, name, salary, project_name, no_projects):
        super().__init__(id, name, salary,project_name)
        self.no_projects = no_projects
 
e = Employee(101,"sowmya",35000)  
t = TeamLead(102,"lakshmi",45000,"Practice tracking project")
m = Manager(103,"sowmyalakshmi",55000,"Exam portal project", 5)
print(e.name, t.name, m.name)
print(e.calculate_salary())
print(t.calculate_salary(5000))
print(t.project_status(90))
print(m.calculate_salary(10000))
print(m.project_status(80))
# Out:
# sowmya lakshmi sowmyalakshmi
# 35000
# 50000
# Practice tracking project project status: 90% completed
# 65000
# Exam portal project project status: 80% completed

# %%
class Father:
    def __init__(self,father_name):
        self.father_name = father_name
    def working(self):
        return "father working as engineer"
class Mother:
    def __init__(self,mother_name):
        self.mother_name = mother_name
    def working(self):
        return"mother working as Teacher"

class child(Father, Mother):
    def __init__(self,name,father_name,mother_name):
        self.name = name
        Father.__init__(self, mother_name)
        Mother.__init__(self, father_name)
    def working(self):
        print(super().working())
        print(super().working())
c= child("sowmya","vamsi","sridevi")
print(c.father_name)
print(c.mother_name)
print(child.__mro__)# Method resolution order
print(c.working())
# Out:
# sridevi
# vamsi
# (<class '__main__.child'>, <class '__main__.Father'>, <class '__main__.Mother'>, <class 'object'>)
# father working as engineer
# father working as engineer
# None

# %%
class Father:
    def __init__(self,father_name):
        self.father_name = father_name
    def working1(self):
        return "father working as engineer"
class Mother:
    def __init__(self,mother_name):
        self.mother_name = mother_name
    def working2(self):
        return"mother working as Teacher"

class child(Father, Mother):
    def __init__(self,name,father_name,mother_name):
        self.name = name
        Father.__init__(self, mother_name)
        Mother.__init__(self, father_name)
    def working(self):
        print(super().working1())
        print(super().working2())
c= child("sowmya","vamsi","sridevi")
print(c.father_name)
print(c.mother_name)
print(child.__mro__)# Method resolution order
print(c.working())
# Out:
# sridevi
# vamsi
# (<class '__main__.child'>, <class '__main__.Father'>, <class '__main__.Mother'>, <class 'object'>)
# father working as engineer
# mother working as Teacher
# None
