# %%
stack=[]
stack.append("https://leetcode.com/problemset/")
stack.append("https://leetcode.com/contest/")
stack.append("https://leetcode.com/discuss/")
stack.append("Insertion Completed")
print(stack)
# Out:
# ['https://leetcode.com/problemset/', 'https://leetcode.com/contest/', 'https://leetcode.com/discuss/', 'Insertion Completed']

# %%
print(stack.pop())
# Out:
# Insertion Completed

# %%
print(stack)
# Out:
# ['https://leetcode.com/problemset/', 'https://leetcode.com/contest/', 'https://leetcode.com/discuss/']

# %%
print(stack.pop())
# Out:
# https://leetcode.com/discuss/

# %%
print(stack)
# Out:
# ['https://leetcode.com/problemset/', 'https://leetcode.com/contest/']

# %%
print(stack.pop())
# Out:
# https://leetcode.com/contest/

# %%
print(stack.pop())
# Out:
# https://leetcode.com/problemset/

# %%
print(stack.pop())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(stack.pop())
#       2
#
# IndexError: pop from empty list

# %%
stack.push()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 stack.push()
#
# AttributeError: 'list' object has no attribute 'push'

# %%
print(dir(stack))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
class Stack:

    def __init__(self):
        self.stack = []
        self.push(10)

    def push(self, value):
        self.stack.append(value)

    def pop(self):
        if self.is_empty():
            return "Stack is empty"
        return self.stack.pop()

    def is_empty(self):
        return len(self.stack) == 0

    def peek(self):
        if self.is_empty():
            print("Stack is empty")
        else:
             return self.stack[-1]


# Creating object
s = Stack()

print(s.stack)

s.push(20)
s.push(30)

print("Stack:", s.stack)
print("Peek:", s.peek())
print("Pop:", s.pop())
print("Stack after pop:", s.stack)

print("Is Empty:", s.is_empty())
# Out:
# [10]
# Stack: [10, 20, 30]
# Peek: 30
# Pop: 30
# Stack after pop: [10, 20]
# Is Empty: False

# %%
class Stack:

    def __init__(self):
        self.stack = []
    def push(self,element):
        self.stack.append(element)
    def deleting(self):
        if self.is_empty():
             return
    def peek(self):
        return self.stack[:-1]
    def is_empty(self):
        return len(self.stack)==0
s1 = Stack()
print(s1.is_empty())
s1.push(10)
s1.push(20)
s1.push(30)
s1.push(40)
print(s1.stack)
print(s1.is_empty())
s1.deleting()
print(s1.peek())
# Out:
# True
# [10, 20, 30, 40]
# False
# [10, 20, 30]

# %%
stack2 = []
stack2.insert(0,10)
print(stack2)
stack2.insert(0,20)
print(stack2)
stack.insert(0,30)
stack.insert(0,40)
print(stack2)
print(stack2.pop(0))
# Out:
# [10]
# [20, 10]
# [20, 10]
# 20
