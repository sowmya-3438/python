# %%
print("hi")

# %% [markdown]
# # Hello
# ## Hello
# ### Hello

# %% [markdown]
# ### string methods
# -Case Conversion methods
#   - upper(): it converts entire string into uppercase
#   - lower(): it converts entire string into lowercase
#   - title(): it converts every word first character into uppercase and remining and
#   - swapcase()
#   - capitalize()

# %%
string = "The ocean is blue and sky is BLUE"
lower = string.lower()
print(lower)
print(string.upper())
print(string.title())
print(string.swapcase())
print(sring.capitalize())

# %%
# white space remove methods
#strip()
#Lstrip()
#rstrip()
string ="          codegnan              "
print(string)
print(string.strip())
print(string.lstrip())
print(string.rstrip())

# %%
#split():it returns the list of substring and by default splits at white space
#split():
string = "The ocean is blue and sky is BLUE 123442@"
print(string.split())
print(string.split('is'))
print(string.split('z'))
print(string.split('blue'))
print(string.split('@')

# %%
#indexing finding methods
#index(sub_string):it returns the first occurance index of substring string exists otherwise "ValueError"
#find(sub_string)
string = "The ocean is blue and sky is blue"
print(string.index("o"))
print(string.index("sky"))
print(string.index('is',14))# it starts checking from 14th index

# %%
#replace(old,new):it replace the old_string with new_string in string
string = "The ocean is blue and sky is BLUE 123442@"
print("string.replace('blue','red'))
