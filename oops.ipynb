# %%
#create mobile class
class Mobile:
    company = "Iphone"
    def __init__(self, model, ram, rom, price):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price
# object creation
iphone16= Mobile("iphone 16", 16, 256, 125000)
iphone17=Mobile("Iphone 17",8, 256, 120000)
print(iphone16.price)
print(iphone17.price)
print(iphone16.company)
print(iphone17.company)
print(Mobile.company)
# Out:
# 125000
# 120000
# Iphone
# Iphone
# Iphone

# %%
#updating instance attribute data from outside class
class Mobile:
    company = "Iphone"
    def __init__(self, model,price, ram=8, rom=256):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price
# object creation
iphone16=Mobile("iphone 16",  80000, 8)
iphone17=Mobile("Iphone 17", 120000, 16)
print(iphone16.ram)
iphone16.ram=16
print(iphone16.ram)
iphone16.company="New Iphone"
print(iphone16.company,iphone17.company)
# Out:
# 8
# 16
# New Iphone Iphone

# %%
class Mobile:
    company = "Iphone"
    def __init__(self, model,price, ram=8, rom=256):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price
    def about_phone(self):
        return f" The {self.model} have {self.ram} GB RAM and {self.rom}GB ROM"
    def display():
        return "This is samsung company display"
    #class method
    @classmethod
    def update_company(cls, new_name):
        cls.company = new_name
        return "Company name Updated"
    #static method
    @staticmethod
    def charge_provide(cable = True):
        return "adpter + cable" if cable else "only adpter"
# object creation
iphone16=Mobile("iphone 16", 16, 256, 80000)
iphone17=Mobile("Iphone 17", 8, 256,120000)
print(iphone16.about_phone())
print(Mobile.display())
print(iphone16.update_company("Iphone Pro"))
print(iphone16.charge_provide())
print(iphone17.company)
# Out:
#  The iphone 16 have 256 GB RAM and 80000GB ROM
# This is samsung company display
# Company name Updated
# adpter + cable
# Iphone Pro

# %%
class Mobile:
    company = "Iphone"
    def __init__(self, model,price, ram=8, rom=256):
        self.model = model
        self.ram = ram
        self.rom = rom
        self.price = price
    def about_phone(self):
        return f" The {self.model} have {self.ram} GB RAM and {self.rom}GB ROM"
    def display():
        return "This is samsung company display"
    #class method
    @classmethod
    def update_company(cls, new_name):
        cls.company = new_name
        return "Company name Updated"
    #static method
    @staticmethod
    def charge_provide(cable = False):
        return "adpter + cable" if cable else "only adpter"
# object creation
iphone16=Mobile("iphone 16", 16, 256, 80000)
iphone17=Mobile("Iphone 17", 8, 256,120000)
#print(iphone16.about_phone())
print(Mobile.display())
print(iphone16.update_company("Iphone Pro"))
print(iphone16.charge_provide())
print(Mobile.company)
# Out:
# This is samsung company display
# Company name Updated
# only adpter
# Iphone Pro

# %%
class Account:
    def __init__(self, acc_no, name, balance=0):
        self.acc_no = acc_no
        self.name = name
        self.balance = balance
    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"₹{amount} deposited successfully.")
        else:
            print("Invalid deposit amount.")

    def withdraw(self, amount):
        if amount <= 0:
            print("Invalid withdrawal amount.")
        elif amount > self.balance:
            print("Insufficient balance.")
        else:
            self.balance -= amount
            print(f"₹{amount} withdrawn successfully.")

    def check_balance(self):
        print(f"Current Balance: ₹{self.balance}")

    def display(self):
        print("\nAccount Details")
        print("Account Number:", self.acc_no)
        print("Account Holder:", self.name)
        print("Balance:", self.balance)


# Example
acc1 = Account(1002, "sowmya", 10000)

acc1.display()
acc1.deposit(3000)
acc1.withdraw(1500)
acc1.check_balance()
# Out:
# Account Details
# Account Number: 1002
# Account Holder: SBI
# Balance: 10000
# ₹3000 deposited successfully.
# ₹1500 withdrawn successfully.
# Current Balance: ₹11500

# %%
class Account:
    def __init__(self,name,balance,password):
        self.name = name
        self.balance = balance
        self.password = password
    def withdraw(self,amount):
        if self.balance >= amount:
            self.balance -= amount
            return f"{amount} withdrawl successfully"
        return "Insufficient Balance"
    def deposite(self, amount):
        self.balance += amount
        return f"{amount} Deposite successfully and current Balance is {self.balance}"
user = Account("sowmya", 5000, "sowmya@123")
print(user.deposite(1000))
user.balance = 100000
print(user.withdraw(10000))
# Out:
# 1000 Deposite successfully and current Balance is 6000
# 10000 withdrawl successfully
