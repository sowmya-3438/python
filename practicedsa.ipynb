# %%
even,odd=2,1
for r in range(1,4):
    for c in range(1,4):
        if r%2==0:
            print(odd,end=" ")
            odd+=2
        else:
            print(even,end=" ")
            even+=2
    print()
# Out:
# 2 4 6
# 1 3 5
# 8 10 12

# %%
for r in range(1,4):
    for c in range(r):
       print("*",end="")
    print()
# Out:
# *
# **
# ***

# %%
for i in range(1,4):
    for j in range(1,4):
        if i>=j:
            print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *
