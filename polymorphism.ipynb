# %%
# Parent Class
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def details(self):
        return f"My name is {self.name} and I am a {self.age} years old"


# Child Class
class Student(Person):
    def __init__(self, name, age, rollno):
        super().__init__(name, age)
        self.rollno = rollno

    # Method Overriding
    def details(self):
       return f"I am a fresher"
p = Person("sowmya",17)
s = Student("pavan",20,1001)
print(p.details())
print(s.details())
# Out:
# My name is sowmya and I am a 17 years old
# I am a fresher

# %%
# Parent Class
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def details(self):
        return f"My name is {self.name} and I am a {self.age} years old"
# Child Class
class Student(Person):
    def __init__(self, name, age, rollno):
        super().__init__(name, age)
        self.rollno = rollno

    # Method Overriding
    def details(self):
        return super().details() + f"I am a student"
p = Person("sowmya",17)
s = Student("pavan",20,1001)
print(s.details())
# Out:
# My name is pavan and I am a 20 years oldI am a student

# %%
class Math:
    def add(self,a,b):
        return a+b
    def add(self,a,b,c):
        return a + b + c
    def add(self,a,b,c,d):
        return a+b+c+d
m = Math()
print(m.add(1,2,3,4))
#print(m.add(1,2,3))
#print(m.add(1,2))
# Out:
# 10

# %%
#python directly dosen't supports method overloading but we can achive through the default arguments or aribatary arguments
class Math:
    
    def add(self,a,b,c=0,d=0):
        return a+b+c+d
mprin = Math()
print(m.add(1,2,3,4))
print(m.add(1,2,3))
print(m.add(1,2))
# Out:
# 10
# 6
# 3

# %%
# Operator overloading 
class point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
p1 = point(5,3)
print(p1)
# Out:
# <__main__.point object at 0x0000018714397230>

# %%
class point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __str__(self): # string magic method
        return f"This  point class and value is:({self.x},{self.y})"
p1 = point(5,3)
print(p1)
# Out:
# This  point class and value is:(5,3)

# %%
class point:
    def __init__(self, x):
        self.x = x
        
    def __str__(self): # string magic method
        return f"This  point class and value is:{self.x}"
p1 = point(5)
p2 = point(3)
print(p1.x + p2.x)
# Out:
# 8

# %%
class point:
    def __init__(self, x):
        self.x = x
        
    def __str__(self): # string magic method
        return f"This  point class and value is:{self.x}"
    def __add__(self,other):
        return self.x + other.x
p1 = point(5)
p2 = point(3)
print(p1.x + p2.x)
print(p1 + p2)
# Out:
# 8
# 8

# %%
class point:
    def __init__(self, x):
        self.x = x
        
    def __str__(self): # string magic method
        return f"This  point class and value is:{self.x}"
    def __add__(self,other):
        return self.x + other.x
    def __sub__(self,other):
        return self.x - other.x
p1 = point(5)
p2 = point(3)
print(p1.x + p2.x)
print(p1 + p2)
print(p1 - p2)
# Out:
# 8
# 8
# 2

# %%
class Point:
    def __init__(self, x):
        self.x = x

    def __str__(self):
        return f"This is Point class and value is: {self.x}"

    def __add__(self, other):
        return str(self.x) + str(other.x)
    def __sub__(self,other):
        return self.x - other.x

p1 = Point(5)
p2 = Point(2)
print(p1.x + p2.x)
print(p1 + p2)
print(p1 - p2)
# Out:
# 7
# 52
# 3

# %%
class Point:
    def __init__(self, x):
        self.x = x

    def __add__(self, other):
        return int(str(self.x) + str(other.x))
    def __sub__(self,other):
        return point(self.x - other.x)



p1 = Point(5)
p2 = Point(3)
p3 = p1 -p2
p4 = point(p3)
print(p1 - p2)
print(p3)
p4 = point(1)
print(type(p3),type(p4))
print(p3 - p4)
# Out:
# This  point class and value is:2
# This  point class and value is:2
# <class '__main__.point'> <class '__main__.point'>
# 1

# %%
print(dir(p1))
# Out:
# ['__add__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__sub__', '__subclasshook__', '__weakref__', 'x']
