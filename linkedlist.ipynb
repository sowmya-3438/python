# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def InsertionAtBeginning(self,new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.next = self.head
            self.head = new_node
    def printingLL(self):
        curr = self.head
        while curr:
            print(curr.data,end = "--->")
            curr = curr.next
        print("None")
LL1 = linkedlist()
LL1.InsertionAtBeginning(10)
LL1.InsertionAtBeginning(20)
LL1.InsertionAtBeginning(30)
LL1.InsertionAtBeginning(40)
LL1.printingLL()
# Out:
# 40--->30--->20--->10--->None

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def InsertionAtBeginning(self,new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.next = self.head
            self.head = new_node
    def InsertionAtEnd(self,new_data):
        new_node =Node(new_data)
        if self.head is None:
            self.head = new_node
        else:
            curr = self.head
            while curr.next:
                curr = curr.next
            curr.next = new_node
    def printingLL(self):
        curr = self.head
        while curr:
            print(curr.data,end = "--->")
            curr = curr.next
        print("None")
    def Searching(self,target):
        self.target = target
        curr = self.head
        count = 0
        while curr:
            count+=1
            if curr.data==target:
                print(f"element found at :{count}")
                count+=1
                break
            curr = curr.next
        else:
            print("element not found")
            
LL1 = linkedlist()
LL1.InsertionAtBeginning(10)
LL1.InsertionAtBeginning(20)
LL1.InsertionAtBeginning(30)
LL1.InsertionAtBeginning(40)
LL1.InsertionAtEnd(1)
LL1.InsertionAtEnd(2)
LL1.InsertionAtEnd(3)
LL1.InsertionAtEnd(4)
LL1.printingLL()
LL1.Searching(10)
# Out:
# 40--->30--->20--->10--->1--->2--->3--->4--->None
# element found at :4

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class linkedlist:
    def __init__(self):
        self.head = None
    def InsertionAtBeginning(self,new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.next = self.head
            self.head = new_node
    def InsertionAtEnd(self,new_data):
        new_node =Node(new_data)
        if self.head is None:
            self.head = new_node
        else:
            curr = self.head
            while curr.next:
                curr = curr.next
            curr.next = new_node
    def count_nodes(self):
        count = 0
        curr = self.head
        while curr:
            count+=1
            curr = curr.next
            return
    def Insertion_After_any_Node(self,pos,new_data):
        self.pos = pos
        c = self.count_nodes()
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
        else:
            curr = self.head
            if c>self.pos:
                for i in range(1,pos-1):
                    curr = curr.next
                    n = curr.next
                    curr.next = new_node
                    new_node.next = n
                else:
                    print(f"insertion can't be position )
            
            
    def printingLL(self):
        curr = self.head
        while curr:
            print(curr.data,end = "--->")
            curr = curr.next
        print("None")
    def Searching(self,target):
        self.target = target
        curr = self.head
        count = 0
        while curr:
            count+=1
            if curr.data==target:
                print(f"element found at :{count}")
                count+=1
                break
            curr = curr.next
        else:
            print("element not found")
            
LL1 = linkedlist()
LL1.InsertionAtBeginning(10)
LL1.InsertionAtBeginning(20)
LL1.InsertionAtBeginning(30)
LL1.InsertionAtBeginning(40)
LL1.InsertionAtEnd(1)
LL1.InsertionAtEnd(2)
LL1.InsertionAtEnd(3)
LL1.InsertionAtEnd(4)
LL1.printingLL()
LL1.Insertion_After_any_Node(3,26)
LL1.printingLL()
LL1.Searching(10)
# Out:
# 40--->30--->20--->10--->1--->2--->3--->4--->None
# 40--->30--->26--->20--->10--->1--->2--->3--->4--->None
# element found at :5
