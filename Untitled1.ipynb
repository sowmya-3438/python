# %%
# reading set of integers
t = tuple(map(int, input().spllit())
print(list(S))
print(tuple(s))
print(str(s)

# %%
# eval()
print("3+5")
print(3+5)
print(eval("3+5"))

# %%
n = eval(input())
print(type(n),n)
